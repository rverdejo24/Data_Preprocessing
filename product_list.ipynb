# %% [markdown]
# # MotorPH Product List
# ## Loading Data Set

# %%
import pandas as pd

product_list = pd.read_csv("raw_data/MotorPH_Products_List_2025.csv")

print(product_list.head().to_string())
# Out:
#    EntrNo                   EntrName                                                  EntrDetails  Manufacturing Date  Acquisiton  UnitPrice
# 0       1              Honda CBR500R         Sport / Parallel-twin, liquid-cooled, 471cc, 6-speed                2021        2023     389000
# 1       2               Yamaha MT-15  Naked bike / Single cylinder, liquid-cooled, 155cc, 6-speed                2022        2023     178000
# 2       3         Kawasaki Ninja 400         Sport / Parallel-twin, liquid-cooled, 399cc, 6-speed                2023        2024     340000
# 3       4      Suzuki Raider R150 Fi   Underbone / Single cylinder, liquid-cooled, 150cc, 6-speed                2020        2021     119900
# 4       5  Royal Enfield Classic 350        Classic / Single cylinder, air-cooled, 349cc, 5-speed                2022        2023     250000

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Check the dataset information

# %%
print(product_list.info())
print()
print(product_list.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EntrNo              50 non-null     int64
#  1   EntrName            50 non-null     str
#  2   EntrDetails         50 non-null     str
#  3   Manufacturing Date  50 non-null     int64
#  4   Acquisiton          50 non-null     int64
#  5   UnitPrice           50 non-null     int64
# dtypes: int64(4), str(2)
# memory usage: 2.5 KB
# None
#
#          EntrNo  Manufacturing Date   Acquisiton      UnitPrice
# count  50.00000           50.000000    50.000000      50.000000
# mean   25.50000         2022.060000  2023.080000  257872.000000
# std    14.57738            0.998162     0.986439  183425.062316
# min     1.00000         2020.000000  2021.000000   48000.000000
# 25%    13.25000         2021.250000  2023.000000  126425.000000
# 50%    25.50000         2022.000000  2023.000000  204950.000000
# 75%    37.75000         2023.000000  2024.000000  330250.000000
# max    50.00000         2023.000000  2024.000000  995000.000000

# %% [markdown]
# Check for missing values

# %%
pd.isnull(product_list).sum()
# Out:
# EntrNo                0
# EntrName              0
# EntrDetails           0
# Manufacturing Date    0
# Acquisiton            0
# UnitPrice             0
# dtype: int64

# %% [markdown]
# The **EntrDetails** column contains different data categories that can be split into different columns. I will place each details into the following categories.
# * Type
# * Engine Configuration
# * Cooling System
# * Displacement (cc)
# * Transmission.

# %%
entr_no = "Product ID Number"
prod_name = "Product Name"
entr_details = "EntrDetails"
prod_type = "Product Type"
engine_conf = "Engine Configuration"
cooling_system = "Cooling System"
displacement = "Displacement (cc)"
transmission = "Transmission"
mfg_year = "Date of Manufacturing"
acquisition_date = "Date of Acquisition"
unit_price = "Unit Price"

new_columns = [entr_no, prod_name, prod_type, engine_conf, cooling_system, displacement, transmission, mfg_year, acquisition_date, unit_price]

split1 = product_list[entr_details].str.split("/", n=1, expand=True)
product_list[prod_type] = split1[0].str.strip()

split2 = split1[1].str.split(",", expand=True)
product_list[engine_conf] = split2[0].str.strip()
product_list[cooling_system] = split2[1].str.strip()
product_list[displacement] = split2[2].str.replace("cc", "", regex=False).astype(int)
product_list[transmission] = split2[3].str.strip()

product_list.drop(columns=[entr_details], inplace=True)


def rename_columns(old_column, new_column):
    product_list.rename(columns={old_column : new_column}, inplace=True)

rename_columns("Acquisiton", acquisition_date)
rename_columns("EntrName", prod_name)
rename_columns("EntrNo", entr_no)
rename_columns("Manufacturing Date", mfg_year)
rename_columns("UnitPrice", unit_price)

product_list = product_list[new_columns]


print(product_list.head().to_string())
# Out:
#    Product ID Number               Product Name Product Type Engine Configuration Cooling System  Displacement (cc) Transmission  Date of Manufacturing  Date of Acquisition  Unit Price
# 0                  1              Honda CBR500R        Sport        Parallel-twin  liquid-cooled                471      6-speed                   2021                 2023      389000
# 1                  2               Yamaha MT-15   Naked bike      Single cylinder  liquid-cooled                155      6-speed                   2022                 2023      178000
# 2                  3         Kawasaki Ninja 400        Sport        Parallel-twin  liquid-cooled                399      6-speed                   2023                 2024      340000
# 3                  4      Suzuki Raider R150 Fi    Underbone      Single cylinder  liquid-cooled                150      6-speed                   2020                 2021      119900
# 4                  5  Royal Enfield Classic 350      Classic      Single cylinder     air-cooled                349      5-speed                   2022                 2023      250000

# %% [markdown]
# ## Export the cleaned data

# %%
product_list.to_csv("cleaned_data/MotorPH_Products_List_2025_cleaned.csv", index=False)
print(product_list.head().to_string())
# Out:
#    Product ID Number               Product Name Product Type Engine Configuration Cooling System  Displacement (cc) Transmission  Date of Manufacturing  Date of Acquisition  Unit Price
# 0                  1              Honda CBR500R        Sport        Parallel-twin  liquid-cooled                471      6-speed                   2021                 2023      389000
# 1                  2               Yamaha MT-15   Naked bike      Single cylinder  liquid-cooled                155      6-speed                   2022                 2023      178000
# 2                  3         Kawasaki Ninja 400        Sport        Parallel-twin  liquid-cooled                399      6-speed                   2023                 2024      340000
# 3                  4      Suzuki Raider R150 Fi    Underbone      Single cylinder  liquid-cooled                150      6-speed                   2020                 2021      119900
# 4                  5  Royal Enfield Classic 350      Classic      Single cylinder     air-cooled                349      5-speed                   2022                 2023      250000

# %% [markdown]
# # Product Analysis #

# %% [markdown]
# ## Load and read the cleaned dataset ##

# %%
product_list = pd.read_csv("cleaned_data/MotorPH_Products_List_2025_cleaned.csv")

# %% [markdown]
# ## Inspect the dataset ##

# %%
print(product_list.columns)
print()
print(product_list.shape)
print()
print(product_list.dtypes)
print()
print(product_list.nunique())
print()
print(product_list.info())
print()
print(product_list["Unit Price"].describe())
# Out:
# Index(['Product ID Number', 'Product Name', 'Product Type',
#        'Engine Configuration', 'Cooling System', 'Displacement (cc)',
#        'Transmission', 'Date of Manufacturing', 'Date of Acquisition',
#        'Unit Price'],
#       dtype='str')
#
# (50, 10)
#
# Product ID Number        int64
# Product Name               str
# Product Type               str
# Engine Configuration       str
# Cooling System             str
# Displacement (cc)        int64
# Transmission               str
# Date of Manufacturing    int64
# Date of Acquisition      int64
# Unit Price               int64
# dtype: object
#
# Product ID Number        50
# Product Name             50
# Product Type             17
# Engine Configuration      5
# Cooling System            4
# Displacement (cc)        31
# Transmission              4
# Date of Manufacturing     4
# Date of Acquisition       4
# Unit Price               46
# dtype: int64
#
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product ID Number      50 non-null     int64
#  1   Product Name           50 non-null     str
#  2   Product Type           50 non-null     str
#  3   Engine Configuration   50 non-null     str
#  4   Cooling System         50 non-null     str
#  5   Displacement (cc)      50 non-null     int64
#  6   Transmission           50 non-null     str
#  7   Date of Manufacturing  50 non-null     int64
#  8   Date of Acquisition    50 non-null     int64
#  9   Unit Price             50 non-null     int64
# dtypes: int64(5), str(5)
# memory usage: 4.0 KB
# None
#
# count        50.000000
# mean     257872.000000
# std      183425.062316
# min       48000.000000
# 25%      126425.000000
# 50%      204950.000000
# 75%      330250.000000
# max      995000.000000
# Name: Unit Price, dtype: float64

# %% [markdown]
# ## View the total number of products ##

# %%
total_products = product_list["Product Name"].count()
print(total_products)
# Out:
# 50

# %% [markdown]
# ## Counts by product type ##

# %%
product_type_counts = product_list.groupby("Product Type")["Product Name"].count().sort_values(ascending=False)
print(product_type_counts)

total_product_types = product_list["Product Type"].nunique()
print(total_product_types)
# Out:
# Product Type
# Scooter          12
# Naked bike        7
# Adventure         4
# Sport             4
# Cruiser           4
# Dual-sport        3
# Underbone         3
# Heritage          2
# Cafe racer        2
# Commuter          2
# Classic           1
# Retro             1
# Scrambler         1
# Sport touring     1
# Standard          1
# Street            1
# Touring           1
# Name: Product Name, dtype: int64
# 17

# %% [markdown]
# ## Unit Price Statistics ##

# %%
average_price = product_list["Unit Price"].mean()
minimum_price = product_list["Unit Price"].min()
maximum_price = product_list["Unit Price"].max()
median_price = product_list["Unit Price"].median()

print(f"Average Price: {average_price:,.2f}")
print(f"Minimum Price: {minimum_price:,.2f}")
print(f"Maximum Price: {maximum_price:,.2f}")
print(f"Median Price: {median_price:,.2f}")
# Out:
# Average Price: 257872.00
# Minimum Price: 48000.00
# Maximum Price: 995000.00
# Median Price: 204950.00

# %% [markdown]
# ## Cheapest Product ##

# %%
cheapest_product = product_list.loc[product_list["Unit Price"].idxmin(),["Product Name", "Product Type", "Unit Price"]]
print(f"Cheapest Product:\n{cheapest_product}")
# Out:
# Cheapest Product:
# Product Name    Rusi Flash 125
# Product Type          Commuter
# Unit Price               48000
# Name: 29, dtype: object

# %% [markdown]
# ## Most Expensive Product ##

# %%
most_expensive_product = product_list.loc[product_list["Unit Price"].idxmax(),["Product Name", "Product Type", "Unit Price"]]
print(f"Most Expensive Product:\n{most_expensive_product}")
# Out:
# Most Expensive Product:
# Product Name    BMW R nineT
# Product Type       Heritage
# Unit Price           995000
# Name: 40, dtype: object

# %% [markdown]
# ## Total Inventory Cost ##

# %%
total_inventory_cost = product_list["Unit Price"].sum()
print(f"Total Inventory Cost: {total_inventory_cost:,.2f}")
# Out:
# Total Inventory Cost: 12893600.00

# %% [markdown]
# ## Number of Products Acquired Each year ##

# %%
acquisition_counts = product_list.groupby("Date of Acquisition")["Product Name"].count().sort_index()
print(acquisition_counts)
# Out:
# Date of Acquisition
# 2021     5
# 2022     7
# 2023    17
# 2024    21
# Name: Product Name, dtype: int64

# %% [markdown]
# ## Highest Acquisition Year and Count ##

# %%
highest_acquisition_year = acquisition_counts.idxmax()
highest_acquisition_count = acquisition_counts.max()

print(f"Highest Acquisition Year: {highest_acquisition_year}"
      f"\nHighest Acquisition Count: {highest_acquisition_count}")
# Out:
# Highest Acquisition Year: 2024
# Highest Acquisition Count: 21

# %% [markdown]
# ## Lowest Acquisition Year and Count ##

# %%
lowest_acquisition_year = acquisition_counts.idxmin()
lowest_acquisition_count = acquisition_counts.min()

print(f"Lowest Acquisition Year: {lowest_acquisition_year}"
      f"\nLowest Acquisition Count: {lowest_acquisition_count}")
# Out:
# Lowest Acquisition Year: 2021
# Lowest Acquisition Count: 5
